# %%
import pandas as pd
import numpy as np
import spacy
from spacy.matcher import Matcher

# model loading
nlp = spacy.load("en_core_web_md")

def find_similar_column(label, all_columns):
    similarities = [(other_column, label.similarity(nlp(other_column.lower()))) for other_column in all_columns]
    similarities.sort(key=lambda x: x[1], reverse=True)
    most_similar = similarities[0][0] if similarities[0][1] > 0.5 else None
    return most_similar

# %%
def perform_analytics(all_labels, df):
    insights = {}
    #cleaning
    #wrong dtypes
    for column in df.columns:
        if df[column].dtype == 'object':
            # Count the number of numeric values in the column
            numeric_count = pd.to_numeric(df[column], errors='coerce').notna().sum()
            
            # Check if 50% or more of the values can be converted to numbers
            if numeric_count / len(df) >= 0.5:
                # Convert the column to float, handling empty strings
                df[column] = pd.to_numeric(df[column].replace('', 'NaN'), errors='coerce').astype(float)
    #null values handling
    df.dropna(inplace = True)
    #duplicate data handling
    if df.duplicated().sum() is True:
        df.drop_duplicates
    #outliers handling
    for column in df.columns:
        if df[column].dtype == 'int64' or df[column].dtype == 'float64':
            mean = df[column].mean()
            std = df[column].std()
            z = (df[column]-mean)/std
            threshold = 3
            outliers = df[abs(z) > threshold]
            df = df[abs(z) <= threshold]
    #reseting dataset indexing 
    df = df.reset_index(drop=True)


    
    # data analysis
    #stage 1 analysis
    for label in all_labels:
        for column in df.columns:            
            if df[column].dtype == 'object':
           
                grouped_data = df.groupby([column, label])[label].count().unstack().fillna(0)
                
                labels = df[column].unique()
                
                
                grouped_data.index = labels
                
                distribution_dict = {
                    f'{label} distribution in {label}': {column_label: count for column_label, count in zip(grouped_data.columns, distribution_row)}
                    for label, distribution_row in zip(grouped_data.index, grouped_data.to_numpy())
                }
                insights[f'{column} distribution in {label} is '] = distribution_dict
                

            


            
            elif df[column].dtype == 'int64' or df[column].dtype == 'float64':
                #numerical analysis
                #here will be upgraded version wwe will build model to predict future values
                
                pass
            
            else:
                break
    #stage 2 analysis
    for label in all_labels:
        for column in df.columns:
            if df[column].dtype == 'int64' or df[column].dtype == 'float64':
                end = df[column].max()
                start = df[column].min()
                end = int(end)
                start = int(start)
                num_ranges = 10
                labl = []
                bin_edge = [start]
                for i in range(start,end,num_ranges):
                    x = (f"{i+1}-{i+num_ranges}")
                    labl.append(x)
                    bin_edge.append(i+num_ranges)
    
                df[column+'_bin'] = pd.cut(df[column], labels = labl, bins = bin_edge)
    
                grouped_data = df.groupby([column+'_bin', label], observed=False)[label].count().unstack().fillna(0)
    
                labels = df[column +'_bin'].unique()
    
                labels = grouped_data.index.get_level_values(0).intersection(labels)
    
                grouped_data = grouped_data.reindex(labels)
    
                distribution_dict = {
                    f'{label} distribution in {label}': {column_label: count for column_label, count in zip(grouped_data.columns, distribution_row)}
                    for label, distribution_row in zip(grouped_data.index, grouped_data.to_numpy())
                }
                insights[f"Distribution of {column} bin in {label} is "] = distribution_dict               
                                 #returning output insight adding left
    return insights

# %%
df = pd.read_csv("CustomerChurn.csv")
null_label = ['all']
print(df.duplicated().sum())
ip_labels = ["Churn"]
dataset_columns = df.columns.values.astype(str)
new_labels = []

for label in ip_labels:
    similar_column = find_similar_column(nlp(label.lower()), dataset_columns)
    if similar_column:
        new_labels.append(similar_column)

# Print similarities for debugging


all_labels = ip_labels + new_labels

print(all_labels)
# Out:
# 0
# ['Churn', 'Churn']
# C:\Users\adity\AppData\Local\Temp\ipykernel_26424\3413661268.py:10: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarities = [(other_column, label.similarity(nlp(other_column.lower()))) for other_column in all_columns]

# %%
#this block of code is temporary to continue development part and later need to be edited as required
if (label in df.columns.values for label in all_labels):
     result = perform_analytics(all_labels, df)
     for key, value in result.items():
         print(key, value)
    
else:
    
    result = default_analytics(null_label, df)
# Out:
# customerID distribution in Churn is  {'7590-VHVEG distribution in 7590-VHVEG': {'No': 1.0, 'Yes': 0.0}, '5575-GNVDE distribution in 5575-GNVDE': {'No': 1.0, 'Yes': 0.0}, '3668-QPYBK distribution in 3668-QPYBK': {'No': 0.0, 'Yes': 1.0}, '7795-CFOCW distribution in 7795-CFOCW': {'No': 0.0, 'Yes': 1.0}, '9237-HQITU distribution in 9237-HQITU': {'No': 0.0, 'Yes': 1.0}, '9305-CDSKC distribution in 9305-CDSKC': {'No': 1.0, 'Yes': 0.0}, '1452-KIOVK distribution in 1452-KIOVK': {'No': 1.0, 'Yes': 0.0}, '6713-OKOMC distribution in 6713-OKOMC': {'No': 1.0, 'Yes': 0.0}, '7892-POOKP distribution in 7892-POOKP': {'No': 1.0, 'Yes': 0.0}, '6388-TABGU distribution in 6388-TABGU': {'No': 1.0, 'Yes': 0.0}, '9763-GRSKD distribution in 9763-GRSKD': {'No': 1.0, 'Yes': 0.0}, '7469-LKBCI distribution in 7469-LKBCI': {'No': 1.0, 'Yes': 0.0}, '8091-TTVAX distribution in 8091-TTVAX': {'No': 1.0, 'Yes': 0.0}, '0280-XJGEX distribution in 0280-XJGEX': {'No': 1.0, 'Yes': 0.0}, '5129-JLPIS distribution in 5129-JLPIS': {'No': 1.0, 'Yes': 0.0}, '3655-SNQYZ distribution in 3655-SNQYZ': {'No': 1.0, 'Yes': 0.0}, '8191-XWSZG distribution in 8191-XWSZG': {'No': 1.0, 'Yes': 0.0}, '9959-WOFKT distribution in 9959-WOFKT': {'No': 1.0, 'Yes': 0.0}, '4190-MFLUW distribution in 4190-MFLUW': {'No': 0.0, 'Yes': 1.0}, '4183-MYFRB distribution in 4183-MYFRB': {'No': 0.0, 'Yes': 1.0}, '8779-QRDMV distribution in 8779-QRDMV': {'No': 1.0, 'Yes': 0.0}, '1680-VDCWW distribution in 1680-VDCWW': {'No': 0.0, 'Yes': 1.0}, '1066-JKSGK distribution in 1066-JKSGK': {'No': 1.0, 'Yes': 0.0}, '3638-WEABW distribution in 3638-WEABW': {'No': 1.0, 'Yes': 0.0}, '6322-HRPFA distribution in 6322-HRPFA': {'No': 0.0, 'Yes': 1.0}, '6865-JZNKO distribution in 6865-JZNKO': {
# gender distribution in Churn is  {'Female distribution in Female': {'No': 2544, 'Yes': 939}, 'Male distribution in Male': {'No': 2619, 'Yes': 930}}
# Partner distribution in Churn is  {'Yes distribution in Yes': {'No': 2439, 'Yes': 1200}, 'No distribution in No': {'No': 2724, 'Yes': 669}}
# Dependents distribution in Churn is  {'No distribution in No': {'No': 3390, 'Yes': 1543}, 'Yes distribution in Yes': {'No': 1773, 'Yes': 326}}
# PhoneService distribution in Churn is  {'No distribution in No': {'No': 510, 'Yes': 170}, 'Yes distribution in Yes': {'No': 4653, 'Yes': 1699}}
# MultipleLines distribution in Churn is  {'No phone service distribution in No phone service': {'No': 2536, 'Yes': 849}, 'No distribution in No': {'No': 510, 'Yes': 170}, 'Yes distribution in Yes': {'No': 2117, 'Yes': 850}}
# InternetService distribution in Churn is  {'DSL distribution in DSL': {'No': 1957, 'Yes': 459}, 'Fiber optic distribution in Fiber optic': {'No': 1799, 'Yes': 1297}, 'No distribution in No': {'No': 1407, 'Yes': 113}}
# OnlineSecurity distribution in Churn is  {'No distribution in No': {'No': 2036, 'Yes': 1461}, 'Yes distribution in Yes': {'No': 1407, 'Yes': 113}, 'No internet service distribution in No internet service': {'No': 1720, 'Yes': 295}}
# OnlineBackup distribution in Churn is  {'Yes distribution in Yes': {'No': 1854, 'Yes': 1233}, 'No distribution in No': {'No': 1407, 'Yes': 113}, 'No internet service distribution in No internet service': {'No': 1902, 'Yes': 523}}
# DeviceProtection distribution in Churn is  {'No distribution in No': {'No': 1883, 'Yes': 1211}, 'Yes distribution in Yes': {'No': 1407, 'Yes': 113}, 'No internet service distribution in No internet service': {'No': 1873, 'Yes': 545}}
# TechSupport distribution in Churn is  {'No distribution in No': {'No': 2026, 'Yes': 1446}, 'Yes distribution in Yes': {'No': 1407, 'Yes': 113}, 'No internet service distribution in No internet service': {'No': 1730, 'Yes': 310}}
# StreamingTV distribution in Churn is  {'No distribution in No': {'No': 1867, 'Yes': 942}, 'Yes distribution in Yes': {'No': 1407, 'Yes': 113}, 'No internet service distribution in No internet service': {'No': 1889, 'Yes': 814}}
# StreamingMovies distribution in Churn is  {'No distribution in No': {'No': 1843, 'Yes': 938}, 'Yes distribution in Yes': {'No': 1407, 'Yes': 113}, 'No internet service distribution in No internet service': {'No': 1913, 'Yes': 818}}
# Contract distribution in Churn is  {'Month-to-month distribution in Month-to-month': {'No': 2220, 'Yes': 1655}, 'One year distribution in One year': {'No': 1306, 'Yes': 166}, 'Two year distribution in Two year': {'No': 1637, 'Yes': 48}}
# PaperlessBilling distribution in Churn is  {'Yes distribution in Yes': {'No': 2395, 'Yes': 469}, 'No distribution in No': {'No': 2768, 'Yes': 1400}}
# PaymentMethod distribution in Churn is  {'Electronic check distribution in Electronic check': {'No': 1284, 'Yes': 258}, 'Mailed check distribution in Mailed check': {'No': 1289, 'Yes': 232}, 'Bank transfer (automatic) distribution in Bank transfer (automatic)': {'No': 1294, 'Yes': 1071}, 'Credit card (automatic) distribution in Credit card (automatic)': {'No': 1296, 'Yes': 308}}
# Churn distribution in Churn is  {'No distribution in No': {'No': 5163.0, 'Yes': 0.0}, 'Yes distribution in Yes': {'No': 0.0, 'Yes': 1869.0}}
# Distribution of SeniorCitizen bin in Churn is  {'1-10 distribution in 1-10': {'No': 666, 'Yes': 476}}
# Distribution of tenure bin in Churn is  {'2-11 distribution in 2-11': {'No': 826, 'Yes': 619}, '12-21 distribution in 12-21': {'No': 603, 'Yes': 269}, '22-31 distribution in 22-31': {'No': 592, 'Yes': 173}, '32-41 distribution in 32-41': {'No': 511, 'Yes': 139}, '42-51 distribution in 42-51': {'No': 541, 'Yes': 109}, '52-61 distribution in 52-61': {'No': 611, 'Yes': 95}, '62-71 distribution in 62-71': {'No': 890, 'Yes': 79}, '72-81 distribution in 72-81': {'No': 356, 'Yes': 6}}
# Distribution of MonthlyCharges bin in Churn is  {'19-28 distribution in 19-28': {'No': 1452, 'Yes': 148}, '29-38 distribution in 29-38': {'No': 132, 'Yes': 57}, '39-48 distribution in 39-48': {'No': 243, 'Yes': 117}, '49-58 distribution in 49-58': {'No': 479, 'Yes': 154}, '59-68 distribution in 59-68': {'No': 419, 'Yes': 52}, '69-78 distribution in 69-78': {'No': 536, 'Yes': 339}, '79-88 distribution in 79-88': {'No': 600, 'Yes': 353}, '89-98 distribution in 89-98': {'No': 552, 'Yes': 313}, '99-108 distribution in 99-108': {'No': 472, 'Yes': 285}, '109-118 distribution in 109-118': {'No': 273, 'Yes': 50}}
# Distribution of TotalCharges bin in Churn is  {'19-28 distribution in 19-28': {'No': 121, 'Yes': 77}, '29-38 distribution in 29-38': {'No': 19, 'Yes': 19}, '39-48 distribution in 39-48': {'No': 56, 'Yes': 46}, '49-58 distribution in 49-58': {'No': 56, 'Yes': 40}, '59-68 distribution in 59-68': {'No': 21, 'Yes': 15}, '69-78 distribution in 69-78': {'No': 40, 'Yes': 126}, '79-88 distribution in 79-88': {'No': 33, 'Yes': 64}, '89-98 distribution in 89-98': {'No': 31, 'Yes': 41}, '99-108 distribution in 99-108': {'No': 22, 'Yes': 13}, '109-118 distribution in 109-118': {'No': 24, 'Yes': 13}, '119-128 distribution in 119-128': {'No': 18, 'Yes': 6}, '129-138 distribution in 129-138': {'No': 25, 'Yes': 13}, '139-148 distribution in 139-148': {'No': 25, 'Yes': 20}, '149-158 distribution in 149-158': {'No': 25, 'Yes': 16}, '159-168 distribution in 159-168': {'No': 24, 'Yes': 19}, '169-178 distribution in 169-178': {'No': 21, 'Yes': 11}, '179-188 distribution in 179-188': {'No': 20, 'Yes': 19}, '189-198 distribution in 189-198': {'No': 18, 'Yes': 16}, '199-208 distribution in 199-208': {'No': 23, 'Yes': 5}, '209-218 distribution in 209-218': {'No': 17, 'Yes': 11}, '219-228 distribution in 219-228': {'No': 30, 'Yes': 15}, '229-238 distribution